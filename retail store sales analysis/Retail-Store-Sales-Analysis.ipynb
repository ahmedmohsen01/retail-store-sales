# %% [markdown]
# ## Importing and Loading DataSet

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r"C:\Users\ahmed\OneDrive\Desktop\retail_store_saless.csv")

# %%
df.head(20)
# Out:
#    Transaction ID Customer ID                       Category          Item  \
# 0     TXN_6867343     CUST_09                     Patisserie   Item_10_PAT
# 1     TXN_3731986     CUST_22                  Milk Products  Item_17_MILK
# 2     TXN_9303719     CUST_02                       Butchers   Item_12_BUT
# 3     TXN_9458126     CUST_06                      Beverages   Item_16_BEV
# 4     TXN_4575373     CUST_05                           Food   Item_6_FOOD
# 5     TXN_7482416     CUST_09                     Patisserie           NaN
# 6     TXN_3652209     CUST_07                           Food   Item_1_FOOD
# 7     TXN_1372952     CUST_21                      Furniture           NaN
# 8     TXN_9728486     CUST_23                      Furniture   Item_16_FUR
# 9     TXN_2722661     CUST_25                       Butchers   Item_22_BUT
# 10    TXN_8776416     CUST_22                       Butchers    Item_3_BUT
# 11    TXN_5422631     CUST_09                  Milk Products           NaN
# 12    TXN_5874772     CUST_23                           Food   Item_2_FOOD
# 13    TXN_4413070     CUST_14                     Patisserie   Item_24_PAT
# 14    TXN_2490363     CUST_09                  Milk Products  Item_16_MILK
# 15    TXN_1809665     CUST_14                      Beverages           NaN
# 16    TXN_7563311     CUST_23                     Patisserie   Item_17_PAT
# 17    TXN_9634894     CUST_15                  Milk Products           NaN
# 18    TXN_4396807     CUST_17  Electric household essentials   Item_13_EHE
# 19    TXN_4206593     CUST_01                      Furniture           NaN
#
#     Price Per Unit  Quantity  Total Spent  Final Sale  Payment Method  \
# 0             18.5      10.0        185.0      166.50  Digital Wallet
# 1             29.0       9.0        261.0      234.90  Digital Wallet
# 2             21.5       2.0         43.0       43.00     Credit Card
# 3             27.5       9.0        247.5      173.25     Credit Card
# 4             12.5       7.0         87.5       87.50  Digital Wallet
# 5              NaN      10.0        200.0      160.00     Credit Card
# 6              5.0       8.0         40.0       36.00     Credit Card
# 7             33.5       NaN          NaN         NaN  Digital Wallet
# 8             27.5       1.0         27.5       27.50     Credit Card
# 9             36.5       3.0        109.5      109.50            Cash
# 10             8.0       9.0         72.0       57.60            Cash
# 11             NaN       8.0         52.0       41.60  Digital Wallet
# 12             6.5       7.0         45.5       36.40            Cash
# 13            39.5       6.0        237.0      237.00  Digital Wallet
# 14            27.5       2.0         55.0       55.00  Digital Wallet
# 15            24.5       NaN          NaN         NaN     Credit Card
# 16            29.0       8.0        232.0      162.40            Cash
# 17             NaN      10.0        275.0      247.50  Digital Wallet
# 18            23.0       1.0         23.0       23.00  Digital Wallet
# 19            35.0       NaN          NaN         NaN  Digital Wallet
#
#     Location Transaction Date Discount Applied
# 0     Online         4/8/2024             True
# 1     Online        7/23/2023             True
# 2     Online        10/5/2022            False
# 3     Online         5/7/2022              NaN
# 4     Online        10/2/2022            False
# 5     Online       11/30/2023              NaN
# 6   In-store        6/10/2023             True
# 7   In-store         4/2/2024             True
# 8   In-store        4/26/2023            False
# 9     Online        3/14/2024            False
# 10  In-store       12/14/2024             True
# 11  In-store        1/12/2025             True
# 12    Online         9/9/2023             True
# 13  In-store        5/20/2022            False
# 14    Online        5/22/2022              NaN
# 15  In-store        5/11/2022              NaN
# 16    Online       11/16/2024             True
# 17    Online        4/17/2022              NaN
# 18  In-store         2/7/2022            False
# 19    Online        1/13/2025            False

# %% [markdown]
# ## Data Cleansing and Pre-Processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              11362 non-null  object
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Final Sale        11971 non-null  float64
#  8   Payment Method    12575 non-null  object
#  9   Location          12575 non-null  object
#  10  Transaction Date  12575 non-null  object
#  11  Discount Applied  8376 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.isnull().mean()*100
# Out:
# Transaction ID       0.000000
# Customer ID          0.000000
# Category             0.000000
# Item                 9.646123
# Price Per Unit       4.842942
# Quantity             4.803181
# Total Spent          4.803181
# Final Sale           4.803181
# Payment Method       0.000000
# Location             0.000000
# Transaction Date     0.000000
# Discount Applied    33.391650
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#        Transaction ID  Customer ID  Category   Item  Price Per Unit  Quantity  \
# 0               False        False     False  False           False     False
# 1               False        False     False  False           False     False
# 2               False        False     False  False           False     False
# 3               False        False     False  False           False     False
# 4               False        False     False  False           False     False
# ...               ...          ...       ...    ...             ...       ...
# 12570           False        False     False  False           False     False
# 12571           False        False     False  False           False     False
# 12572           False        False     False  False           False     False
# 12573           False        False     False  False           False     False
# 12574           False        False     False  False           False     False
#
#        Total Spent  Final Sale  Payment Method  Location  Transaction Date  \
# 0            False       False           False     False             False
# 1            False       False           False     False             False
# 2            False       False           False     False             False
# 3            False       False           False     False             False
# 4            False       False           False     False             False
# ...            ...         ...             ...       ...               ...
# 12570        False       False           False     False             False
# 12571        False       False           False     False             False
# 12572        False       False           False     False             False
# 12573        False       False           False     False             False
# 12574        False       False           False     False             False
#
#        Discount Applied
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False
# ...                 ...
# 12570              True
# 12571             False
# 12572              True
# 12573             False
# 12574              True
#
# [12575 rows x 12 columns]

# %%
from pandas import value_counts


value_counts((df['Discount Applied']))
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_32060\1639784827.py:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   value_counts((df['Discount Applied']))
# Discount Applied
# True     4219
# False    4157
# Name: count, dtype: int64

# %%
def isdiscounted(row):
    if row['Final Sale'] < row['Total Spent']:
        return True
    elif row['Final Sale'] == row['Total Spent']:
        return False
    else:
        return None

# %%
df['Discount Applied'] = df.apply(isdiscounted, axis=1)

# %%
df
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Final Sale  Payment Method  Location  \
# 0          10.0        185.0      166.50  Digital Wallet    Online
# 1           9.0        261.0      234.90  Digital Wallet    Online
# 2           2.0         43.0       43.00     Credit Card    Online
# 3           9.0        247.5      173.25     Credit Card    Online
# 4           7.0         87.5       87.50  Digital Wallet    Online
# ...         ...          ...         ...             ...       ...
# 12570       4.0        152.0      136.80     Credit Card  In-store
# 12571       9.0         58.5       58.50            Cash    Online
# 12572      10.0        140.0      112.00            Cash    Online
# 12573       6.0         84.0       67.20            Cash    Online
# 12574       3.0         51.0       51.00            Cash    Online
#
#       Transaction Date Discount Applied
# 0             4/8/2024             True
# 1            7/23/2023             True
# 2            10/5/2022            False
# 3             5/7/2022             True
# 4            10/2/2022            False
# ...                ...              ...
# 12570         9/3/2023             True
# 12571        8/12/2022            False
# 12572        8/24/2024             True
# 12573       12/30/2023             True
# 12574         8/6/2022            False
#
# [12575 rows x 12 columns]

# %%
def logic_null_resolution(row):
    if pd.isna(row['Price Per Unit']) and pd.notna(row['Quantity']) and pd.notna(row['Total Spent']):
        row['Price Per Unit'] = row['Total Spent'] / row['Quantity']
    elif pd.notna(row['Price Per Unit']) and pd.isna(row['Quantity']) and pd.notna(row['Total Spent']):
        row['Quantity'] = row['Total Spent'] / row['Price Per Unit']
    elif pd.notna(row['Price Per Unit']) and pd.notna(row['Quantity']) and pd.isna(row['Total Spent']):
        row['Total Spent'] = row['Price Per Unit'] * row['Quantity']
        
    
    return row

# %%
df = df.apply(logic_null_resolution, axis=1)

# %%
df.head(20)
# Out:
#    Transaction ID Customer ID                       Category          Item  \
# 0     TXN_6867343     CUST_09                     Patisserie   Item_10_PAT
# 1     TXN_3731986     CUST_22                  Milk Products  Item_17_MILK
# 2     TXN_9303719     CUST_02                       Butchers   Item_12_BUT
# 3     TXN_9458126     CUST_06                      Beverages   Item_16_BEV
# 4     TXN_4575373     CUST_05                           Food   Item_6_FOOD
# 5     TXN_7482416     CUST_09                     Patisserie           NaN
# 6     TXN_3652209     CUST_07                           Food   Item_1_FOOD
# 7     TXN_1372952     CUST_21                      Furniture           NaN
# 8     TXN_9728486     CUST_23                      Furniture   Item_16_FUR
# 9     TXN_2722661     CUST_25                       Butchers   Item_22_BUT
# 10    TXN_8776416     CUST_22                       Butchers    Item_3_BUT
# 11    TXN_5422631     CUST_09                  Milk Products           NaN
# 12    TXN_5874772     CUST_23                           Food   Item_2_FOOD
# 13    TXN_4413070     CUST_14                     Patisserie   Item_24_PAT
# 14    TXN_2490363     CUST_09                  Milk Products  Item_16_MILK
# 15    TXN_1809665     CUST_14                      Beverages           NaN
# 16    TXN_7563311     CUST_23                     Patisserie   Item_17_PAT
# 17    TXN_9634894     CUST_15                  Milk Products           NaN
# 18    TXN_4396807     CUST_17  Electric household essentials   Item_13_EHE
# 19    TXN_4206593     CUST_01                      Furniture           NaN
#
#     Price Per Unit  Quantity  Total Spent  Final Sale  Payment Method  \
# 0             18.5      10.0        185.0      166.50  Digital Wallet
# 1             29.0       9.0        261.0      234.90  Digital Wallet
# 2             21.5       2.0         43.0       43.00     Credit Card
# 3             27.5       9.0        247.5      173.25     Credit Card
# 4             12.5       7.0         87.5       87.50  Digital Wallet
# 5             20.0      10.0        200.0      160.00     Credit Card
# 6              5.0       8.0         40.0       36.00     Credit Card
# 7             33.5       NaN          NaN         NaN  Digital Wallet
# 8             27.5       1.0         27.5       27.50     Credit Card
# 9             36.5       3.0        109.5      109.50            Cash
# 10             8.0       9.0         72.0       57.60            Cash
# 11             6.5       8.0         52.0       41.60  Digital Wallet
# 12             6.5       7.0         45.5       36.40            Cash
# 13            39.5       6.0        237.0      237.00  Digital Wallet
# 14            27.5       2.0         55.0       55.00  Digital Wallet
# 15            24.5       NaN          NaN         NaN     Credit Card
# 16            29.0       8.0        232.0      162.40            Cash
# 17            27.5      10.0        275.0      247.50  Digital Wallet
# 18            23.0       1.0         23.0       23.00  Digital Wallet
# 19            35.0       NaN          NaN         NaN  Digital Wallet
#
#     Location Transaction Date Discount Applied
# 0     Online         4/8/2024             True
# 1     Online        7/23/2023             True
# 2     Online        10/5/2022            False
# 3     Online         5/7/2022             True
# 4     Online        10/2/2022            False
# 5     Online       11/30/2023             True
# 6   In-store        6/10/2023             True
# 7   In-store         4/2/2024             None
# 8   In-store        4/26/2023            False
# 9     Online        3/14/2024            False
# 10  In-store       12/14/2024             True
# 11  In-store        1/12/2025             True
# 12    Online         9/9/2023             True
# 13  In-store        5/20/2022            False
# 14    Online        5/22/2022            False
# 15  In-store        5/11/2022             None
# 16    Online       11/16/2024             True
# 17    Online        4/17/2022             True
# 18  In-store         2/7/2022            False
# 19    Online        1/13/2025             None

# %%
null_rows = df[df['Quantity'].isna() & df['Total Spent'].isna() & df['Item'].isna()]

# %%
null_rows
# Out:
#       Transaction ID Customer ID                       Category Item  \
# 7        TXN_1372952     CUST_21                      Furniture  NaN
# 15       TXN_1809665     CUST_14                      Beverages  NaN
# 19       TXN_4206593     CUST_01                      Furniture  NaN
# 25       TXN_3481599     CUST_05                      Furniture  NaN
# 34       TXN_1621497     CUST_06                     Patisserie  NaN
# ...              ...         ...                            ...  ...
# 12527    TXN_1069238     CUST_23                           Food  NaN
# 12552    TXN_4823896     CUST_05                  Milk Products  NaN
# 12556    TXN_4397672     CUST_04                      Beverages  NaN
# 12562    TXN_7422454     CUST_07                       Butchers  NaN
# 12564    TXN_2153066     CUST_17  Electric household essentials  NaN
#
#        Price Per Unit  Quantity  Total Spent  Final Sale  Payment Method  \
# 7                33.5       NaN          NaN         NaN  Digital Wallet
# 15               24.5       NaN          NaN         NaN     Credit Card
# 19               35.0       NaN          NaN         NaN  Digital Wallet
# 25               39.5       NaN          NaN         NaN            Cash
# 34               23.0       NaN          NaN         NaN            Cash
# ...               ...       ...          ...         ...             ...
# 12527             5.0       NaN          NaN         NaN  Digital Wallet
# 12552             8.0       NaN          NaN         NaN            Cash
# 12556            41.0       NaN          NaN         NaN     Credit Card
# 12562            33.5       NaN          NaN         NaN            Cash
# 12564            29.0       NaN          NaN         NaN  Digital Wallet
#
#        Location Transaction Date Discount Applied
# 7      In-store         4/2/2024             None
# 15     In-store        5/11/2022             None
# 19       Online        1/13/2025             None
# 25       Online         9/8/2022             None
# 34     In-store        2/18/2023             None
# ...         ...              ...              ...
# 12527  In-store        8/13/2022             None
# 12552  In-store        7/21/2022             None
# 12556    Online       11/28/2024             None
# 12562    Online        4/15/2023             None
# 12564  In-store        3/28/2024             None
#
# [604 rows x 12 columns]

# %%
df_cleaned = df.dropna(subset=['Quantity', 'Total Spent','Item'], how='all')

# %%
df_cleaned
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Final Sale  Payment Method  Location  \
# 0          10.0        185.0      166.50  Digital Wallet    Online
# 1           9.0        261.0      234.90  Digital Wallet    Online
# 2           2.0         43.0       43.00     Credit Card    Online
# 3           9.0        247.5      173.25     Credit Card    Online
# 4           7.0         87.5       87.50  Digital Wallet    Online
# ...         ...          ...         ...             ...       ...
# 12570       4.0        152.0      136.80     Credit Card  In-store
# 12571       9.0         58.5       58.50            Cash    Online
# 12572      10.0        140.0      112.00            Cash    Online
# 12573       6.0         84.0       67.20            Cash    Online
# 12574       3.0         51.0       51.00            Cash    Online
#
#       Transaction Date Discount Applied
# 0             4/8/2024             True
# 1            7/23/2023             True
# 2            10/5/2022            False
# 3             5/7/2022             True
# 4            10/2/2022            False
# ...                ...              ...
# 12570         9/3/2023             True
# 12571        8/12/2022            False
# 12572        8/24/2024             True
# 12573       12/30/2023             True
# 12574         8/6/2022            False
#
# [11971 rows x 12 columns]

# %%
rows_with_na = df_cleaned[df_cleaned.isna().any(axis=1)]
rows_with_na
# Out:
#       Transaction ID Customer ID                            Category Item  \
# 5        TXN_7482416     CUST_09                          Patisserie  NaN
# 11       TXN_5422631     CUST_09                       Milk Products  NaN
# 17       TXN_9634894     CUST_15                       Milk Products  NaN
# 21       TXN_8685338     CUST_15                       Milk Products  NaN
# 32       TXN_1543244     CUST_20                                Food  NaN
# ...              ...         ...                                 ...  ...
# 12435    TXN_5147764     CUST_01                           Furniture  NaN
# 12457    TXN_1352194     CUST_17       Electric household essentials  NaN
# 12477    TXN_5625684     CUST_22  Computers and electric accessories  NaN
# 12491    TXN_7894525     CUST_23                            Butchers  NaN
# 12511    TXN_5715500     CUST_17                                Food  NaN
#
#        Price Per Unit  Quantity  Total Spent  Final Sale  Payment Method  \
# 5                20.0      10.0        200.0       160.0     Credit Card
# 11                6.5       8.0         52.0        41.6  Digital Wallet
# 17               27.5      10.0        275.0       247.5  Digital Wallet
# 21               35.0       3.0        105.0        84.0     Credit Card
# 32               24.5       8.0        196.0       176.4     Credit Card
# ...               ...       ...          ...         ...             ...
# 12435             6.5       5.0         32.5        26.0     Credit Card
# 12457            21.5       4.0         86.0        60.2     Credit Card
# 12477            20.0       4.0         80.0        56.0            Cash
# 12491            26.0       1.0         26.0        23.4     Credit Card
# 12511            33.5       3.0        100.5       100.5  Digital Wallet
#
#        Location Transaction Date Discount Applied
# 5        Online       11/30/2023             True
# 11     In-store        1/12/2025             True
# 17       Online        4/17/2022             True
# 21     In-store       10/29/2023             True
# 32       Online       10/25/2024             True
# ...         ...              ...              ...
# 12435    Online         9/6/2023             True
# 12457    Online        2/26/2023             True
# 12477  In-store        11/9/2022             True
# 12491    Online        1/31/2023             True
# 12511    Online         6/5/2024            False
#
# [609 rows x 12 columns]

# %%
grouped = df.groupby(['Category', 'Price Per Unit'])['Item']

# Check if all items in each group are the same
inconsistent_groups = grouped.nunique().reset_index()
inconsistent_groups = inconsistent_groups[inconsistent_groups['Item'] > 1]

if inconsistent_groups.empty:
    print("All items with the same category and price per unit is the same")
else:
    print("they are not the same")
    print(inconsistent_groups)
# Out:
# All items with the same category and price per unit is the same

# %%
def fill_missing_item(df):
    for index, row in df[df['Item'].isna()].iterrows():
        matching_row = df.loc[
            (df['Category'] == row['Category']) & 
            (df['Price Per Unit'] == row['Price Per Unit']) & 
            (df['Item'].notna())
        ]
        if not matching_row.empty:
            df.at[index, 'Item'] = matching_row.iloc[0]['Item']
    
    return df

# %%
df_cleaned = fill_missing_item(df_cleaned)

# %%
df_cleaned
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Final Sale  Payment Method  Location  \
# 0          10.0        185.0      166.50  Digital Wallet    Online
# 1           9.0        261.0      234.90  Digital Wallet    Online
# 2           2.0         43.0       43.00     Credit Card    Online
# 3           9.0        247.5      173.25     Credit Card    Online
# 4           7.0         87.5       87.50  Digital Wallet    Online
# ...         ...          ...         ...             ...       ...
# 12570       4.0        152.0      136.80     Credit Card  In-store
# 12571       9.0         58.5       58.50            Cash    Online
# 12572      10.0        140.0      112.00            Cash    Online
# 12573       6.0         84.0       67.20            Cash    Online
# 12574       3.0         51.0       51.00            Cash    Online
#
#       Transaction Date Discount Applied
# 0             4/8/2024             True
# 1            7/23/2023             True
# 2            10/5/2022            False
# 3             5/7/2022             True
# 4            10/2/2022            False
# ...                ...              ...
# 12570         9/3/2023             True
# 12571        8/12/2022            False
# 12572        8/24/2024             True
# 12573       12/30/2023             True
# 12574         8/6/2022            False
#
# [11971 rows x 12 columns]

# %% [markdown]
# ## Adjusting DataTypes

# %%
df_cleaned.dtypes
# Out:
# Transaction ID       object
# Customer ID          object
# Category             object
# Item                 object
# Price Per Unit      float64
# Quantity            float64
# Total Spent         float64
# Final Sale          float64
# Payment Method       object
# Location             object
# Transaction Date     object
# Discount Applied     object
# dtype: object

# %%
df_cleaned = df_cleaned.convert_dtypes()

# %%
df_cleaned.dtypes
# Out:
# Transaction ID      string[python]
# Customer ID         string[python]
# Category            string[python]
# Item                string[python]
# Price Per Unit             Float64
# Quantity                     Int64
# Total Spent                Float64
# Final Sale                 Float64
# Payment Method      string[python]
# Location            string[python]
# Transaction Date    string[python]
# Discount Applied           boolean
# dtype: object

# %%
df_cleaned['Transaction Date'] = pd.to_datetime(df_cleaned['Transaction Date'])

# %%
df_cleaned.dtypes
# Out:
# Transaction ID      string[python]
# Customer ID         string[python]
# Category            string[python]
# Item                string[python]
# Price Per Unit             Float64
# Quantity                     Int64
# Total Spent                Float64
# Final Sale                 Float64
# Payment Method      string[python]
# Location            string[python]
# Transaction Date    datetime64[ns]
# Discount Applied           boolean
# dtype: object

# %% [markdown]
# ## Adding some columns could be useful

# %%
df_cleaned['Percentage of Discount'] = 100- (df_cleaned['Final Sale'] / df_cleaned['Total Spent'] * 100)

# %%
df_cleaned
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Final Sale  Payment Method  Location  \
# 0            10        185.0       166.5  Digital Wallet    Online
# 1             9        261.0       234.9  Digital Wallet    Online
# 2             2         43.0        43.0     Credit Card    Online
# 3             9        247.5      173.25     Credit Card    Online
# 4             7         87.5        87.5  Digital Wallet    Online
# ...         ...          ...         ...             ...       ...
# 12570         4        152.0       136.8     Credit Card  In-store
# 12571         9         58.5        58.5            Cash    Online
# 12572        10        140.0       112.0            Cash    Online
# 12573         6         84.0        67.2            Cash    Online
# 12574         3         51.0        51.0            Cash    Online
#
#       Transaction Date  Discount Applied  Percentage of Discount
# 0           2024-04-08              True                    10.0
# 1           2023-07-23              True                    10.0
# 2           2022-10-05             False                     0.0
# 3           2022-05-07              True                    30.0
# 4           2022-10-02             False                     0.0
# ...                ...               ...                     ...
# 12570       2023-09-03              True                    10.0
# 12571       2022-08-12             False                     0.0
# 12572       2024-08-24              True                    20.0
# 12573       2023-12-30              True                    20.0
# 12574       2022-08-06             False                     0.0
#
# [11971 rows x 13 columns]

# %%
df_cleaned['Is Weekend'] = df_cleaned['Transaction Date'].dt.day_name().isin(['Thursday', 'Friday', 'Saturday']).replace({True: 'True', False: 'False'})

# %%
df_cleaned
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Final Sale  Payment Method  Location  \
# 0            10        185.0       166.5  Digital Wallet    Online
# 1             9        261.0       234.9  Digital Wallet    Online
# 2             2         43.0        43.0     Credit Card    Online
# 3             9        247.5      173.25     Credit Card    Online
# 4             7         87.5        87.5  Digital Wallet    Online
# ...         ...          ...         ...             ...       ...
# 12570         4        152.0       136.8     Credit Card  In-store
# 12571         9         58.5        58.5            Cash    Online
# 12572        10        140.0       112.0            Cash    Online
# 12573         6         84.0        67.2            Cash    Online
# 12574         3         51.0        51.0            Cash    Online
#
#       Transaction Date  Discount Applied  Percentage of Discount Is Weekend
# 0           2024-04-08              True                    10.0      False
# 1           2023-07-23              True                    10.0      False
# 2           2022-10-05             False                     0.0      False
# 3           2022-05-07              True                    30.0       True
# 4           2022-10-02             False                     0.0      False
# ...                ...               ...                     ...        ...
# 12570       2023-09-03              True                    10.0      False
# 12571       2022-08-12             False                     0.0       True
# 12572       2024-08-24              True                    20.0       True
# 12573       2023-12-30              True                    20.0       True
# 12574       2022-08-06             False                     0.0       True
#
# [11971 rows x 14 columns]

# %% [markdown]
# ## Checking for outliers

# %%
import seaborn as sns

# %%
sns.boxplot(x='Price Per Unit', data=df_cleaned)
sns.stripplot(x='Price Per Unit', data=df_cleaned, color="#474646")
# Out:
# <Axes: xlabel='Price Per Unit'>

# %%
sns.boxplot(x='Quantity', data=df_cleaned)
sns.stripplot(x='Quantity', data=df_cleaned, color="#474646")
# Out:
# <Axes: xlabel='Quantity'>

# %%
sns.boxplot(x='Total Spent', data=df_cleaned)
sns.stripplot(x='Total Spent', data=df_cleaned, color="#474646")
# Out:
# <Axes: xlabel='Total Spent'>

# %%
df_cleaned['Customer ID'].unique()
# Out:
# <StringArray>
# ['CUST_09', 'CUST_22', 'CUST_02', 'CUST_06', 'CUST_05', 'CUST_07', 'CUST_23',
#  'CUST_25', 'CUST_14', 'CUST_15', 'CUST_17', 'CUST_10', 'CUST_04', 'CUST_13',
#  'CUST_18', 'CUST_08', 'CUST_20', 'CUST_12', 'CUST_11', 'CUST_19', 'CUST_16',
#  'CUST_24', 'CUST_21', 'CUST_01', 'CUST_03']
# Length: 25, dtype: string

# %%
df_cleaned.to_csv(r'C:\Users\ahmed\Documents\cleaned_data.csv')

# %% [markdown]
# ## Deploying StreamLit With Analytical Dashboard

# %%
# %%writefile app.py

import pandas as pd
from pandas.core import groupby
import plotly.express as px
import streamlit as st
from datetime import datetime


st.set_page_config(layout='wide')
df = pd.read_csv(r'C:\Users\ahmed\Documents\cleaned_data.csv')
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

## Title of the page
st.markdown(
    """
    <h1 style="text-align: center; white: black;">Retail Store Sales</h1>
    """,
    unsafe_allow_html=True
)


time_range = st.selectbox(
    "Select Time Range:",
    options=["Current Month", "Current Year", "Last Year", "All Time", "Custom Range"],
    index=3  
)


if time_range == "Custom Range":
    start_date = st.date_input("From", min_value=datetime(2000, 1, 1), max_value=datetime.now())
    end_date = st.date_input("To", min_value=start_date, max_value=datetime.now())
    df = df[(df['Transaction Date'] >= pd.to_datetime(start_date)) & (df['Transaction Date'] <= pd.to_datetime(end_date))]
else:
    current_date = datetime.now()
    if time_range == "Current Month":
        df = df[(df['Transaction Date'].dt.month == current_date.month) & (df['Transaction Date'].dt.year == current_date.year)]
    elif time_range == "Current Year":
        df = df[df['Transaction Date'].dt.year == current_date.year]
    elif time_range == "Last Year":
        df = df[df['Transaction Date'].dt.year == current_date.year - 1]

## Total sales orders
row_count = df['Transaction ID'].count()
if row_count < 1000 :
    formatted_count = f'{row_count}'
elif row_count > 1000 and row_count <1000000 :
    formatted_count = f"{row_count / 1000:.1f}k "
elif row_count > 1000000  :
    formatted_count = f"{row_count / 1000000:.1f}M"

## Total revenue
total_revenue = sum(df['Final Sale'])
if total_revenue < 1000:
    formatted_revenue = f"{total_revenue} EGP"
elif 1000 <= total_revenue < 1000000:
    formatted_revenue = f"{total_revenue / 1000:.1f}k EGP"
elif total_revenue >= 1000000:
    formatted_revenue = f"{total_revenue / 1000000:.1f}M EGP"

## total sold items
total_sold_items = sum(df['Quantity'])

if total_sold_items < 1000 :
    formatted_sold_items = f'{total_sold_items} Item'
elif total_sold_items >=  1000 and total_sold_items < 1000000 : 
    formatted_sold_items = f"{total_sold_items / 1000:.1f}k Item"
elif total_sold_items > 1000000 : 
    formatted_sold_items = f"{total_sold_items / 1000000:.1f}M Item"

## Average Order Value
average_order_value = (sum(df['Final Sale']) / row_count)
if average_order_value < 1000 :
    formatted_avg_value = f"{round(average_order_value,2)} EGP"
elif average_order_value >=  1000 and average_order_value < 1000000 : 
    formatted_avg_value = f"{round(average_order_value,2) / 1000:.1f}k EGP"
elif average_order_value > 1000000 : 
    formatted_avg_value = f"{round(average_order_value,2) / 1000000:.1f}M EGP"

##Group By Category


main_col1, main_col2 = st.columns(2)

with main_col1:
    sub_col1, sub_col2 = st.columns(2)
    
    with sub_col1:
        st.subheader('Total Sales Orders')
        st.markdown(
            f"""
            <h1 style="font-size:48px; color:green;">{formatted_count}</h1>
             """,
            unsafe_allow_html=True
        )

        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')



        st.subheader('Total Sold Items')
        st.markdown(
            f"""
            <h1 style="font-size:48px; color:green;">{formatted_sold_items}</h1>
             """,
            unsafe_allow_html=True
        )

    with sub_col2:
        st.subheader('Total Revenue')
        st.markdown(
            f"""
            <h1 style="font-size:48px; color:green;">{formatted_revenue}</h1>
             """,
            unsafe_allow_html=True
        )

        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        st.write('')
        
        st.subheader('Average Order Value')
        st.markdown(
            f"""
            <h1 style="font-size:48px; color:green;">{formatted_avg_value}</h1>
             """,
            unsafe_allow_html=True
        )

with main_col2:
    sub_col4 = st.columns(1)[0]  
    with sub_col4:
        st.subheader('Distribution Of Sold Categories')
        st.plotly_chart(px.pie(data_frame=df, names='Category' ,color_discrete_sequence=px.colors.sequential.Viridis , hole = 0.5))

sub_col3 = st.columns(1)[0] 
with sub_col3:
        st.subheader('Products Performance')
        st.plotly_chart(px.histogram(data_frame=df , x= df['Item']))

main_col3, main_col4 = st.columns(2)

with main_col3:
    sub_col1, sub_col2 = st.columns(2)
    
    with sub_col1:
        st.subheader('Top 5 Sold Products')
        top_5_items = df['Item'].value_counts().head(5).reset_index()
        top_5_df = pd.DataFrame(top_5_items)
        st.plotly_chart(px.histogram(data_frame=top_5_df, x='Item',y= 'count',color_discrete_sequence=['green']))

    with sub_col2:
        st.subheader('Least 5 Sold Products')
        top_5_items = df['Item'].value_counts().tail(5).reset_index()
        top_5_df = pd.DataFrame(top_5_items)
        st.plotly_chart(px.histogram(data_frame=top_5_df, x='Item',y= 'count',color_discrete_sequence=['red']))
    
with main_col4 :
    st.subheader('Payment Method Distribution')
    st.plotly_chart(px.pie(data_frame=df , names = df['Payment Method'] , hole = 0.5, color_discrete_sequence= px.colors.sequential.Viridis))


## Sales order by month 
df['Month'] = df['Transaction Date'].dt.month_name()
sales_orders_in_month = df.groupby('Month').size().reset_index(name='Number of Orders')

# Sort the DataFrame by calendar month order
sales_orders_in_month['Month'] = pd.Categorical(
    sales_orders_in_month['Month'],
    categories=['January', 'February', 'March', 'April', 'May', 'June', 
                'July', 'August', 'September', 'October', 'November', 'December'],
    ordered=True
)
sales_orders_in_month = sales_orders_in_month.sort_values('Month')
pd.DataFrame(sales_orders_in_month).reset_index()


sub_col4 = st.columns(1)[0] 
with sub_col4:
    fig = px.line(
        sales_orders_in_month, 
        x='Month', 
        y='Number of Orders', 
        markers=True,  
        title='Sales Orders by Month'
    )
    st.plotly_chart(fig)

## Sales order by WeekDay 

df['WeekDay'] = df['Transaction Date'].dt.day_name()
sales_orders_in_day = df.groupby('WeekDay').size().reset_index(name='Number of Orders')
sales_orders_in_day['WeekDay'] = pd.Categorical(
    sales_orders_in_day['WeekDay'],
    categories=['Saturday', 'Sunday', 'Monday', 'Tuesday' , 'Wednnsday' , 'Thursday' , 'Friday' ,],
    ordered=True
)
sales_orders_in_day = sales_orders_in_day.sort_values('WeekDay')
pd.DataFrame(sales_orders_in_day).reset_index()

## Revenue By Category
category_revenue = df.groupby('Category').sum('Final Sale').reset_index()
result = category_revenue.filter(['Category', 'Final Sale'])
pd.DataFrame(result)

## Revenue By Customer
category_revenue = df.groupby('Customer ID').sum('Final Sale').reset_index()
result2 = category_revenue.filter(['Customer ID', 'Final Sale'])
pd.DataFrame(result2)

## Revenue By Location
location_revenue = df.groupby('Location').sum('Final Sale').reset_index()
result3 = location_revenue.filter(['Location', 'Final Sale'])
pd.DataFrame(result3)

main_col5, main_col6 = st.columns(2)
with main_col5 :
    st.plotly_chart(px.line(sales_orders_in_day , x='WeekDay' , y= 'Number of Orders' , markers = True , title = 'Sales Orders By Day'))
    st.plotly_chart(px.histogram(data_frame=df , x= df['Location'] , title = 'Location Distribution Of Sold Orders'))
    st.plotly_chart(px.bar(data_frame=result , x = result['Category'] , y=result['Final Sale'] , title= 'Total Revenue by Category' , color_discrete_sequence= ['green']))
    st.plotly_chart(
    px.histogram(
        data_frame=result,
        x=result3['Final Sale'],
        y=result3['Location'],
        title='Total Revenue by Location',
        color_discrete_sequence=['green'],
        labels={
            'x': 'Final Sale (EGP)',  # Label for the x-axis
            'y': 'Location',         # Label for the y-axis
        }
    )
    )



with main_col6 :
    st.plotly_chart(px.pie(data_frame=df , names= df['Is Weekend'] , title='Orders Sold In Weekend?' , color_discrete_sequence= px.colors.sequential.Viridis))
    st.plotly_chart(px.bar(data_frame=df , x = df['Discount Applied'] , title = 'Orders With Discount Applied'))
    st.plotly_chart(px.line(data_frame= result2 , x='Customer ID' , y= 'Final Sale' , markers = True , title = 'Customers Spent'))
    fig = px.scatter(
    df,
    x='Percentage of Discount',
    y='Final Sale',
    title='Discount Percentage vs. Total Revenue',
    labels={'Percentage of Discount': 'Discount Percentage (%)', 'Final Sale': 'Total Revenue (EGP)'},
    color='Percentage of Discount',  # Optional: Color by discount percentage
    size='Final Sale')
    st.plotly_chart(fig)
# Out:
# Overwriting app.py

# %%
! streamlit run app.py
# Out:
# ^C
